# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\amitk\OneDrive\Documents\archive (32)\final_dataset.csv")
df
# Out:
#       Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0        1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1        2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2        3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3        4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4        5      1  2021               0     2   54.06   55.54  122.66   9.70
# ...    ...    ...   ...             ...   ...     ...     ...     ...    ...
# 1456    27     12  2024               0     5   58.43  249.17   41.69  65.89
# 1457    28     12  2024               0     6   33.83  150.77   33.31  66.14
# 1458    29     12  2024               1     7   31.21  139.75   27.01  65.94
# 1459    30     12  2024               0     1   38.01  152.83   29.12  65.16
# 1460    31     12  2024               0     2   80.42  318.96   40.37  64.98
#
#         CO  Ozone  AQI
# ...

# %%
df.isnull().sum()
# Out:
# Date              0
# Month             0
# Year              0
# Holidays_Count    0
# Days              0
# PM2.5             0
# PM10              0
# NO2               0
# SO2               0
# CO                0
# Ozone             0
# AQI               0
# dtype: int64

# %%
df["Days"] = df["Days"].astype(str)

# %%
di = {
    "1":"Monday",
    "2":"Tuesday",
    "3":"Wednesday",
    "4":"Thursday",
    "5":"Friday",
    "6":"Saturday",
    "7":"Sunday"
}

# %%
df["Days"].replace(di,inplace=True)
# Out:
# C:\Users\amitk\AppData\Local\Temp\ipykernel_12308\3612507088.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Days"].replace(di,inplace=True)

# %%
df
# Out:
#       Date  Month  Year  Holidays_Count      Days   PM2.5    PM10     NO2  \
# 0        1      1  2021               0    Friday  408.80  442.42  160.61
# 1        2      1  2021               0  Saturday  404.04  561.95   52.85
# 2        3      1  2021               1    Sunday  225.07  239.04  170.95
# 3        4      1  2021               0    Monday   89.55  132.08  153.98
# 4        5      1  2021               0   Tuesday   54.06   55.54  122.66
# ...    ...    ...   ...             ...       ...     ...     ...     ...
# 1456    27     12  2024               0    Friday   58.43  249.17   41.69
# 1457    28     12  2024               0  Saturday   33.83  150.77   33.31
# 1458    29     12  2024               1    Sunday   31.21  139.75   27.01
# 1459    30     12  2024               0    Monday   38.01  152.83   29.12
# 1460    31     12  2024               0   Tuesday   80.42  318.96   40.37
#
#         SO2    CO  Ozone  AQI
# 0     12.95  2.77  43.19  462
# ...

# %%
m = {
    1:"January",
    2:"Febuary",
    3:"March",
    4:"April",
    5:"May",
    6:"June",
    7:"July",
    8:"August",
    9:"September",
    10:"October",
    11:"November",
    12:"December"
}

# %%
df["Month"].replace(m,inplace=True)
# Out:
# C:\Users\amitk\AppData\Local\Temp\ipykernel_12308\2276606271.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Month"].replace(m,inplace=True)

# %%
df
# Out:
#       Date     Month  Year  Holidays_Count      Days   PM2.5    PM10     NO2  \
# 0        1   January  2021               0    Friday  408.80  442.42  160.61
# 1        2   January  2021               0  Saturday  404.04  561.95   52.85
# 2        3   January  2021               1    Sunday  225.07  239.04  170.95
# 3        4   January  2021               0    Monday   89.55  132.08  153.98
# 4        5   January  2021               0   Tuesday   54.06   55.54  122.66
# ...    ...       ...   ...             ...       ...     ...     ...     ...
# 1456    27  December  2024               0    Friday   58.43  249.17   41.69
# 1457    28  December  2024               0  Saturday   33.83  150.77   33.31
# 1458    29  December  2024               1    Sunday   31.21  139.75   27.01
# 1459    30  December  2024               0    Monday   38.01  152.83   29.12
# 1460    31  December  2024               0   Tuesday   80.42  318.96   40.37
#
#         SO2    CO  Ozone  AQI
# ...

# %% [markdown]
# # What is the average AQI per Month

# %%
group = df.groupby("Month")["AQI"].mean().sort_values(ascending=False)
group
# Out:
# Month
# November     342.133333
# January      305.685484
# December     297.266129
# Febuary      239.734513
# April        222.350000
# March        200.129032
# May          199.717742
# October      191.637097
# June         163.983333
# July          90.354839
# August        89.790323
# September     87.300000
# Name: AQI, dtype: float64

# %%
group.plot(kind="bar")
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# # Which month in each year recordedthe highest average PH2.5 levels

# %%
y21 = df[df["Year"]==2021]
y22 = df[df["Year"]==2022]
y23 = df[df["Year"]==2023]
y24 = df[df["Year"]==2024]

# %%
g21 = y21.groupby("Month")["PM2.5"].mean().sort_values(ascending=False)[:1]
g22 = y22.groupby("Month")["PM2.5"].mean().sort_values(ascending=False)[:1]
g23 = y23.groupby("Month")["PM2.5"].mean().sort_values(ascending=False)[:1]
g24 = y24.groupby("Month")["PM2.5"].mean().sort_values(ascending=False)[:1]

# %%
print("Year 2021")
print(g21)
print("Year 2022")
print(g22)
print("Year 2023")
print(g23)
print("Year 2024")
print(g24)
# Out:
# Year 2021
# Month
# November    243.365
# Name: PM2.5, dtype: float64
# Year 2022
# Month
# April    161.924667
# Name: PM2.5, dtype: float64
# Year 2023
# Month
# January    158.01
# Name: PM2.5, dtype: float64
# Year 2024
# Month
# November    138.728667
# Name: PM2.5, dtype: float64

# %% [markdown]
# # Is there a correlation between PM10 and AQI

# %%
cor = df[["PM10","AQI"]]
cor
# Out:
#         PM10  AQI
# 0     442.42  462
# 1     561.95  482
# 2     239.04  263
# 3     132.08  207
# 4      55.54  149
# ...      ...  ...
# 1456  249.17  263
# 1457  150.77  113
# 1458  139.75  142
# 1459  152.83  116
# 1460  318.96  209
#
# [1461 rows x 2 columns]

# %%
correlation = cor["AQI"].corr(cor["PM10"])
print(f"correlation B/W PM10 & AQI is {correlation*100}%")
plt.scatter(cor["PM10"],cor["AQI"])
plt.title("AQI vs PM10")
plt.xlabel("PM10")
plt.ylabel("AQI")
plt.show()
# Out:
# correlation B/W PM10 & AQI is 89.94209019355367%

# %% [markdown]
# # How does AQI vary on holiday compared to non-holidays?

# %%
holiday = df[df["Holidays_Count"] == 1]
non_holiday = df[df["Holidays_Count"] == 0]

# %%
avg1 = holiday["AQI"].mean()
avg2 = non_holiday["AQI"].mean()

# %%
print("Holiday AQi average")
print(avg1)
print("Holiday AQI average")
print(avg2)
# Out:
# Holiday AQi average
# 202.31046931407943
# Holiday AQI average
# 202.1875

# %%
li = [avg1,avg2]
label = ["Holidasys","Non_holidays"]

plt.pie(li,labels = label,autopct = "%.2f",radius = 0.7,shadow = True)
plt.show()

# %% [markdown]
# # What is the trend of NO2 levels over the Years?

# %%
df
# Out:
#       Date     Month  Year  Holidays_Count      Days   PM2.5    PM10     NO2  \
# 0        1   January  2021               0    Friday  408.80  442.42  160.61
# 1        2   January  2021               0  Saturday  404.04  561.95   52.85
# 2        3   January  2021               1    Sunday  225.07  239.04  170.95
# 3        4   January  2021               0    Monday   89.55  132.08  153.98
# 4        5   January  2021               0   Tuesday   54.06   55.54  122.66
# ...    ...       ...   ...             ...       ...     ...     ...     ...
# 1456    27  December  2024               0    Friday   58.43  249.17   41.69
# 1457    28  December  2024               0  Saturday   33.83  150.77   33.31
# 1458    29  December  2024               1    Sunday   31.21  139.75   27.01
# 1459    30  December  2024               0    Monday   38.01  152.83   29.12
# 1460    31  December  2024               0   Tuesday   80.42  318.96   40.37
#
#         SO2    CO  Ozone  AQI
# ...

# %%
df["Year"] = df["Year"].astype(str)

# %%
group = df.groupby("Year")["NO2"].mean().plot(kind="line")

# %% [markdown]
# # Which pollutant shows the strongest correlation with AQI

# %%
cor = df[["PM2.5","PM10","NO2","SO2","CO","Ozone","AQI"]]
cor
# Out:
#        PM2.5    PM10     NO2    SO2    CO  Ozone  AQI
# 0     408.80  442.42  160.61  12.95  2.77  43.19  462
# 1     404.04  561.95   52.85   5.18  2.60  16.43  482
# 2     225.07  239.04  170.95  10.93  1.40  44.29  263
# 3      89.55  132.08  153.98  10.42  1.01  49.19  207
# 4      54.06   55.54  122.66   9.70  0.64  48.88  149
# ...      ...     ...     ...    ...   ...    ...  ...
# 1456   58.43  249.17   41.69  65.89  0.99  36.25  263
# 1457   33.83  150.77   33.31  66.14  0.79  35.19  113
# 1458   31.21  139.75   27.01  65.94  0.57  35.88  142
# 1459   38.01  152.83   29.12  65.16  0.55  38.38  116
# 1460   80.42  318.96   40.37  64.98  0.84  39.93  209
#
# [1461 rows x 7 columns]

# %%
correlation = cor["AQI"].corr(cor["PM10"])
print(f"correlation B/W PM2 AQI is {correlation*100}%")

correlation = cor["AQI"].corr(cor["PM2.5"])
print(f"correlation B/W PM2.5 AQI is {correlation*100}%")

correlation = cor["AQI"].corr(cor["NO2"])
print(f"correlation B/W NO2 AQI is {correlation*100}%")

correlation = cor["AQI"].corr(cor["SO2"])
print(f"correlation B/W SO2 AQI is {correlation*100}%")

correlation = cor["AQI"].corr(cor["CO"])
print(f"correlation B/W CO AQI is {correlation*100}%")

correlation = cor["AQI"].corr(cor["Ozone"])
print(f"correlation B/W Ozone AQI is {correlation*100}%")
print()


fig,ax=plt.subplots(3,2)
ax[0,0].scatter(cor["PM10"],cor["AQI"],marker=".")
ax[0,0].set_title("AQI vs PM10")
ax[0,0].set_xlabel("PM10")
ax[0,0].set_ylabel("AQI")

ax[0,1].scatter(cor["PM2.5"],cor["AQI"],marker=".")
ax[0,1].set_title("AQI vs PM2.5")
ax[0,1].set_xlabel("PM2.5")
ax[0,1].set_ylabel("AQI")

ax[1,0].scatter(cor["NO2"],cor["AQI"],marker=".")
ax[1,0].set_title("AQI vs NO2")
ax[1,0].set_xlabel("NO2")
ax[1,0].set_ylabel("AQI")

ax[1,1].scatter(cor["SO2"],cor["AQI"],marker=".")
ax[1,1].set_title("AQI vs SO2")
ax[1,1].set_xlabel("SO2")
ax[1,1].set_ylabel("AQI")

ax[2,0].scatter(cor["CO"],cor["AQI"],marker=".")
ax[2,0].set_title("AQI vs CO")
ax[2,0].set_xlabel("CO")
ax[2,0].set_ylabel("AQI")

ax[2,1].scatter(cor["Ozone"],cor["AQI"],marker = ".")
ax[2,1].set_title("AQI vs Ozone")
ax[2,1].set_xlabel("Ozone")
ax[2,1].set_ylabel("AQI")

plt.tight_layout()
# Out:
# correlation B/W PM2 AQI is 89.94209019355367%
# correlation B/W PM2.5 AQI is 80.19599648277625%
# correlation B/W NO2 AQI is 31.92609845811225%
# correlation B/W SO2 AQI is 3.6287863123406363%
# correlation B/W CO AQI is 69.68090340688339%
# correlation B/W Ozone AQI is -16.428141188750896%

# %% [markdown]
# # On how many days did PM2.5 exceed the who safe limit (e.g.,) 25

# %%
above_limit = df[df["PM2.5"]>25].count()[0]
below_limit = df[df["PM2.5"]<25].count()[0]
# Out:
# C:\Users\amitk\AppData\Local\Temp\ipykernel_12308\382585373.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   above_limit = df[df["PM2.5"]>25].count()[0]
# C:\Users\amitk\AppData\Local\Temp\ipykernel_12308\382585373.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   below_limit = df[df["PM2.5"]<25].count()[0]

# %%
print(f"Days count Above who safe limits = {above_limit}")
print()
print(f"Days count Above who safe limits = {below_limit}")
li = [above_limit,below_limit]
label = ["Unsafe","Safe"]
plt.pie(li,labels = label ,autopct="%.2f",shadow = True ,radius = 0.8)
plt.title("Who safe limits")
plt.show()
# Out:
# Days count Above who safe limits = 1360
#
# Days count Above who safe limits = 100
