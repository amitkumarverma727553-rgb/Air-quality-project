# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HARSH KHANNA\Downloads\Forbes_2000_Companies_2025.csv", sep = None , engine = "python")
df
# Out:
#       Rank                                   Company    Headquarters  \
# 0        1                             JPMorganChase   United States
# 1        2                        Berkshire Hathaway   United States
# 2        3                                      ICBC           China
# 3        4  Saudi Arabian Oil Company (Saudi Aramco)    Saudi Arabia
# 4        5                                    Amazon   United States
# ...    ...                                       ...             ...
# 1995  1996                               Dino Polska          Poland
# 1996  1997                        China Aviation Oil       Singapore
# 1997  1998                                      Jet2  United Kingdom
# 1998  1998                                Keiyo Bank           Japan
# 1999  1998                         PT Lippo Karawaci       Indonesia
#
#                           Industry  Sales ($B) Profit ($B) Assets ($B)  \
# ...

# %% [markdown]
# # Q1

# %%
country = list(df["Headquarters"])
print(country)
# Out:
# ['United States', 'United States', 'China', 'Saudi Arabia', 'United States', 'United States', 'China', 'China', 'United States', 'United States', 'United States', 'China', 'United States', 'Japan', 'United Kingdom', 'United States', 'United States', 'United States', 'South Korea', 'United States', 'United States', 'United States', 'United Kingdom', 'United States', 'Germany', 'Canada', 'China', 'China', 'Spain', 'United States', 'United States', 'Hong Kong', 'China', 'Japan', 'United States', 'France', 'China', 'Taiwan', 'China', 'Germany', 'France', 'United States', 'United States', 'France', 'India', 'Canada', 'United States', 'Switzerland', 'France', 'United States', 'China', 'Spain', 'India', 'Germany', 'India', 'Japan', 'China', 'Japan', 'China', 'United States', 'Italy', 'Germany', 'Australia', 'Switzerland', 'France', 'United States', 'United States', 'United States', 'United States', 'Switzerland', 'United States', 'Germany', 'United States', 'United States', 'China', 'United
# ...

# %%
n_america = ["United States" , "Canada" , "Mexico"]
s_america = ["Brazil" , "Argentina"]
asia = ["India" , "China" , "Japan" , "South Korea" , "Taiwan" , "Hong Kong" , "Indonesia" , "Singapore" , "Thailand" , "Malaysia"]
middle_east = ["Saudi Arabia" , "Qatar" , "Iran" , "Isreal" , "United Arab Emirates"]
australia = ["Australia"]
africa = ["South Africa"]
europe = []

continent = []

for i in country:
    if i in n_america:
        continent.append("North America")
    elif i in s_america:
        continent.append("South America")
    elif i in asia:
        continent.append("Asia")
    elif i in middle_east:
        continent.append("Middle East")
    elif i in australia:
        continent.append("Australia")
    elif i in africa:
        continent.append("Africa")
    else:
        continent.append("Europe")

# %%
print(continent)
# Out:
# ['North America', 'North America', 'Asia', 'Middle East', 'North America', 'North America', 'Asia', 'Asia', 'North America', 'North America', 'North America', 'Asia', 'North America', 'Asia', 'Europe', 'North America', 'North America', 'North America', 'Asia', 'North America', 'North America', 'North America', 'Europe', 'North America', 'Europe', 'North America', 'Asia', 'Asia', 'Europe', 'North America', 'North America', 'Asia', 'Asia', 'Asia', 'North America', 'Europe', 'Asia', 'Asia', 'Asia', 'Europe', 'Europe', 'North America', 'North America', 'Europe', 'Asia', 'North America', 'North America', 'Europe', 'Europe', 'North America', 'Asia', 'Europe', 'Asia', 'Europe', 'Asia', 'Asia', 'Asia', 'Asia', 'Asia', 'North America', 'Europe', 'Europe', 'Australia', 'Europe', 'Europe', 'North America', 'North America', 'North America', 'North America', 'Europe', 'North America', 'Europe', 'North America', 'North America', 'Asia', 'North America', 'Europe', 'Europe', 'Asia', 'Europe', 'Europ
# ...

# %%
df["Continent"] = continent

# %%
df
# Out:
#       Rank                                   Company    Headquarters  \
# 0        1                             JPMorganChase   United States
# 1        2                        Berkshire Hathaway   United States
# 2        3                                      ICBC           China
# 3        4  Saudi Arabian Oil Company (Saudi Aramco)    Saudi Arabia
# 4        5                                    Amazon   United States
# ...    ...                                       ...             ...
# 1995  1996                               Dino Polska          Poland
# 1996  1997                        China Aviation Oil       Singapore
# 1997  1998                                      Jet2  United Kingdom
# 1998  1998                                Keiyo Bank           Japan
# 1999  1998                         PT Lippo Karawaci       Indonesia
#
#                           Industry  Sales ($B) Profit ($B) Assets ($B)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               2000 non-null   int64
#  1   Company            2000 non-null   object
#  2   Headquarters       2000 non-null   object
#  3   Industry           2000 non-null   object
#  4   Sales ($B)         2000 non-null   float64
#  5   Profit ($B)        2000 non-null   object
#  6   Assets ($B)        2000 non-null   object
#  7   Market Value ($B)  2000 non-null   object
#  8   Continent          2000 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 140.8+ KB

# %%
profit = list(df["Profit ($B)"])
pro = []
for i in profit:
    if i.count(".") > 1:
        pro.append(0)
    else:
        pro.append(float(i))

# %%
print(pro)
# Out:
# [59.36, 89.0, 50.84, 104.97, 59.25, 27.85, 46.64, 39.2, 111.0, 92.75, 96.15, 32.3, 33.68, 33.65, 22.97, 20.0, 22.11, 19.44, 24.65, 14.88, 62.36, 13.25, 16.12, 14.29, 10.59, 12.9, 17.61, 22.88, 13.6, 17.66, 17.78, 19.31, 16.72, 12.82, 11.85, 11.73, 26.97, 40.32, 20.62, 12.12, 15.78, 21.81, 15.71, 8.31, 8.24, 6.39, 72.88, 12.36, 13.58, 10.2, 6.99, 10.77, 8.37, 11.6, 9.48, 8.62, 12.22, 7.48, 12.02, 15.5, 9.37, 10.4, 6.44, 5.08, 6.88, 12.16, 14.81, 10.07, 6.37, 5.82, 5.62, 11.04, 8.02, 4.61, 10.73, 17.43, 8.46, 6.15, 7.39, 9.4, 7.89, 7.62, 5.15, 5.92, 19.17, 9.37, 6.21, 7.59, 14.86, 5.89, 4.6, 5.85, 7.62, 9.19, 5.47, 8.72, 7.23, 5.92, 6.79, 11.95, 8.04, 4.88, 6.01, 10.63, 9.22, 8.79, 4.8, 4.17, 7.05, 6.66, 9.53, 6.07, 8.45, 4.03, 6.04, 10.38, 6.88, 10.79, 4.58, 3.43, 7.51, 7.09, 6.97, 6.49, 11.39, 19.7, 5.88, 4.43, 5.49, 5.6, 6.01, 4.59, 4.08, 6.79, 11.55, 6.42, 4.75, 10.59, 5.26, 4.6, 6.29, 9.1, 5.01, 13.46, 6.23, 6.0, 6.2, 6.52, 6.22, 4.31, 6.53, 5.72, 15.62, 6.84, 18.64, 5.77, 4.72, 1
# ...

# %%
df["Profit ($B)"]  = pro

# %%
df
# Out:
#       Rank                                   Company    Headquarters  \
# 0        1                             JPMorganChase   United States
# 1        2                        Berkshire Hathaway   United States
# 2        3                                      ICBC           China
# 3        4  Saudi Arabian Oil Company (Saudi Aramco)    Saudi Arabia
# 4        5                                    Amazon   United States
# ...    ...                                       ...             ...
# 1995  1996                               Dino Polska          Poland
# 1996  1997                        China Aviation Oil       Singapore
# 1997  1998                                      Jet2  United Kingdom
# 1998  1998                                Keiyo Bank           Japan
# 1999  1998                         PT Lippo Karawaci       Indonesia
#
#                           Industry  Sales ($B)  Profit ($B) Assets ($B)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               2000 non-null   int64
#  1   Company            2000 non-null   object
#  2   Headquarters       2000 non-null   object
#  3   Industry           2000 non-null   object
#  4   Sales ($B)         2000 non-null   float64
#  5   Profit ($B)        2000 non-null   float64
#  6   Assets ($B)        2000 non-null   object
#  7   Market Value ($B)  2000 non-null   object
#  8   Continent          2000 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 140.8+ KB

# %%
df["Profit Margin"] = df["Profit ($B)"] / df["Sales ($B)"]
df
# Out:
#       Rank                                   Company    Headquarters  \
# 0        1                             JPMorganChase   United States
# 1        2                        Berkshire Hathaway   United States
# 2        3                                      ICBC           China
# 3        4  Saudi Arabian Oil Company (Saudi Aramco)    Saudi Arabia
# 4        5                                    Amazon   United States
# ...    ...                                       ...             ...
# 1995  1996                               Dino Polska          Poland
# 1996  1997                        China Aviation Oil       Singapore
# 1997  1998                                      Jet2  United Kingdom
# 1998  1998                                Keiyo Bank           Japan
# 1999  1998                         PT Lippo Karawaci       Indonesia
#
#                           Industry  Sales ($B)  Profit ($B) Assets ($B)  \
# ...

# %%
p = list(df["Profit Margin"])
m = []
for i in p:
    m.append(f"{i}%")

# %%
n = []
for i in m:
    n.append(f"{i[:4]}%")

# %%
a = []
for i in n:
    a.append(f"{i[2:]}")

# %%
df["Profit Margin"] = a

# %%
df
# Out:
#       Rank                                   Company    Headquarters  \
# 0        1                             JPMorganChase   United States
# 1        2                        Berkshire Hathaway   United States
# 2        3                                      ICBC           China
# 3        4  Saudi Arabian Oil Company (Saudi Aramco)    Saudi Arabia
# 4        5                                    Amazon   United States
# ...    ...                                       ...             ...
# 1995  1996                               Dino Polska          Poland
# 1996  1997                        China Aviation Oil       Singapore
# 1997  1998                                      Jet2  United Kingdom
# 1998  1998                                Keiyo Bank           Japan
# 1999  1998                         PT Lippo Karawaci       Indonesia
#
#                           Industry  Sales ($B)  Profit ($B) Assets ($B)  \
# ...

# %%
sales = df.groupby("Continent")["Sales ($B)"].sum()
sales.sort_values(ascending = False).plot(kind = "bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df
# Out:
#       Rank                                   Company    Headquarters  \
# 0        1                             JPMorganChase   United States
# 1        2                        Berkshire Hathaway   United States
# 2        3                                      ICBC           China
# 3        4  Saudi Arabian Oil Company (Saudi Aramco)    Saudi Arabia
# 4        5                                    Amazon   United States
# ...    ...                                       ...             ...
# 1995  1996                               Dino Polska          Poland
# 1996  1997                        China Aviation Oil       Singapore
# 1997  1998                                      Jet2  United Kingdom
# 1998  1998                                Keiyo Bank           Japan
# 1999  1998                         PT Lippo Karawaci       Indonesia
#
#                           Industry  Sales ($B)  Profit ($B) Assets ($B)  \
# ...

# %% [markdown]
# # Q2

# %%
df["Industry"].value_counts()
# Out:
# Industry
# Banking                                   326
# Diversified Financials                    134
# Insurance                                 119
# Construction                              109
# Utilities                                  96
# IT Software & Services                     94
# Oil & Gas Operations                       93
# Materials                                  87
# Food, Drink & Tobacco                      85
# Transportation                             84
# Consumer Durables                          80
# Retailing                                  79
# Business Services & Supplies               76
# Capital Goods                              75
# Technology Hardware & Equipment            60
# Drugs & Biotechnology                      57
# Health Care Equipment & Services           49
# Chemicals                                  46
# Telecommunications Services                43
# Trading Companies                          34
# ...

# %%
banking = df[df["Industry"] == "Banking"]

# %%
banking.head(2)
# Out:
#    Rank        Company   Headquarters Industry  Sales ($B)  Profit ($B)  \
# 0     1  JPMorganChase  United States  Banking      285.11        59.36
# 2     3           ICBC          China  Banking      221.96        50.84
#
#   Assets ($B) Market Value ($B)      Continent Profit Margin
# 0   4,357.86             677.8   North America           20%
# 2    6,688.6            251.33            Asia           22%

# %%
it = df[df["Industry"] == "IT Software & Services"]
it.head(2)
# Out:
#    Rank    Company   Headquarters                Industry  Sales ($B)  \
# 8     9   Alphabet  United States  IT Software & Services      359.31
# 9     9  Microsoft  United States  IT Software & Services      261.80
#
#    Profit ($B) Assets ($B) Market Value ($B)      Continent Profit Margin
# 8       111.00     475.37          1,973.64   North America           30%
# 9        92.75      533.9          2,913.01   North America           35%

# %%
food = df[df["Industry"] == "Food, Drink & Tobacco"]
food.head(1)
# Out:
#     Rank Company Headquarters               Industry  Sales ($B)  Profit ($B)  \
# 47    48  Nestlé  Switzerland  Food, Drink & Tobacco      103.73        12.36
#
#    Assets ($B) Market Value ($B) Continent Profit Margin
# 47     153.67            265.65     Europe           11%

# %%
oil = df[df["Industry"] == "Oil & Gas Operations"]
oil.head(1)
# Out:
#    Rank                                   Company  Headquarters  \
# 3     4  Saudi Arabian Oil Company (Saudi Aramco)  Saudi Arabia
#
#                Industry  Sales ($B)  Profit ($B) Assets ($B)  \
# 3  Oil & Gas Operations      480.15       104.97     645.03
#
#   Market Value ($B)    Continent Profit Margin
# 3         1,663.38   Middle East           21%

# %%
import numpy as np

# %%
fig , ax = plt.subplots(2,2)

ax[0,0].scatter(banking["Assets ($B)"] , banking["Market Value ($B)"] , marker = ".")
ax[0,0].set_xticks([])
ax[0,0].set_yticks([])
ax[0,0].set_xlabel("Assets (in $B)")
ax[0,0].set_ylabel("Market Value (in ($B))")
ax[0,0].set_title("Banking")

ax[0,1].scatter(it["Assets ($B)"] , it["Market Value ($B)"] , marker = ".")
ax[0,1].set_xticks([])
ax[0,1].set_yticks([])
ax[0,1].set_xlabel("Assets (in $B)")
ax[0,1].set_ylabel("Market Value (in ($B))")
ax[0,1].set_title("IT Softwares")

ax[1,0].scatter(oil["Assets ($B)"] , oil["Market Value ($B)"] , marker = ".")
ax[1,0].set_xticks([])
ax[1,0].set_yticks([])
ax[1,0].set_xlabel("Assets (in $B)")
ax[1,0].set_ylabel("Market Value (in ($B))")
ax[1,0].set_title("Oil & Gas")

ax[1,1].scatter(food["Assets ($B)"] , food["Market Value ($B)"] , marker = ".")
ax[1,1].set_xticks([])
ax[1,1].set_yticks([])
ax[1,1].set_xlabel("Assets (in $B)")
ax[1,1].set_ylabel("Market Value (in ($B))")
ax[1,1].set_title("Food")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Q3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               2000 non-null   int64
#  1   Company            2000 non-null   object
#  2   Headquarters       2000 non-null   object
#  3   Industry           2000 non-null   object
#  4   Sales ($B)         2000 non-null   float64
#  5   Profit ($B)        2000 non-null   float64
#  6   Assets ($B)        2000 non-null   object
#  7   Market Value ($B)  2000 non-null   object
#  8   Continent          2000 non-null   object
#  9   Profit Margin      2000 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 156.4+ KB

# %%
mv = list(df["Market Value ($B)"])
print(mv)
# Out:
# ['677.8 ', '1,145.46 ', '251.33 ', '1,663.38 ', '2,005.64 ', '300.06 ', '219.81 ', '212.51 ', '1,973.64 ', '2,913.01 ', '3,143.82 ', '164.71 ', '469.6 ', '244.39 ', '196.16 ', '227.44 ', '382.94 ', '762.32 ', '259.77 ', '169.34 ', '1,381.87 ', '127.81 ', '195.55 ', '187.11 ', '157.55 ', '166.38 ', '107.27 ', '136.38 ', '110.41 ', '242.32 ', '176.86 ', '223.47 ', '285.47 ', '139.79 ', '192.45 ', '93.5 ', '562.27 ', '708.2 ', '143.87 ', '173.71 ', '125.83 ', '372.51 ', '128.18 ', '100.33 ', '205.91 ', '108.88 ', '2,708.64 ', '265.65 ', '283.06 ', '185.52 ', '94.58 ', '81.51 ', '171.09 ', '55.71 ', '83.43 ', '87.95 ', '64.43 ', '147.94 ', '60.98 ', '377.57 ', '94.28 ', '184.52 ', '176.01 ', '91.25 ', '57.76 ', '388.36 ', '355.41 ', '904.23 ', '916.55 ', '97.54 ', '163.21 ', '59.76 ', '129.99 ', '82.46 ', '59.72 ', '208.21 ', '111.83 ', '89.45 ', '85.23 ', '251.06 ', '54.01 ', '65.56 ', '58.6 ', '69.24 ', '103.31 ', '182.91 ', '155.43 ', '86.93 ', '51.01 ', '60.45 ', '167.29 ', '128.73 '
# ...

# %%
count = 0
a = []
b = []
for i in mv:
    try:
        i = float(i)
        a.append(i)
    except:
        count += 1
        i = i.replace("," , "")
        a.append(i)

# %%
print(count)
# Out:
# 8

# %%
print(b)
# Out:
# []

# %%
print(a)
# Out:
# [677.8, '1145.46 ', 251.33, '1663.38 ', '2005.64 ', 300.06, 219.81, 212.51, '1973.64 ', '2913.01 ', '3143.82 ', 164.71, 469.6, 244.39, 196.16, 227.44, 382.94, 762.32, 259.77, 169.34, '1381.87 ', 127.81, 195.55, 187.11, 157.55, 166.38, 107.27, 136.38, 110.41, 242.32, 176.86, 223.47, 285.47, 139.79, 192.45, 93.5, 562.27, 708.2, 143.87, 173.71, 125.83, 372.51, 128.18, 100.33, 205.91, 108.88, '2708.64 ', 265.65, 283.06, 185.52, 94.58, 81.51, 171.09, 55.71, 83.43, 87.95, 64.43, 147.94, 60.98, 377.57, 94.28, 184.52, 176.01, 91.25, 57.76, 388.36, 355.41, 904.23, 916.55, 97.54, 163.21, 59.76, 129.99, 82.46, 59.72, 208.21, 111.83, 89.45, 85.23, 251.06, 54.01, 65.56, 58.6, 69.24, 103.31, 182.91, 155.43, 86.93, 51.01, 60.45, 167.29, 128.73, 433.55, 225.61, 215.5, 155.36, 73.97, 95.27, 68.43, 211.63, 34.5, 60.78, 45.52, 309.47, 115.95, 62.39, 69.98, 329.14, 214.62, 62.2, 43.62, 109.87, 91.21, 55.28, 117.09, 90.08, 46.32, 146.46, 125.95, 90.92, 142.51, 73.05, 211.6, 144.98, 123.44, 654.78, 39.92,
# ...

# %%
df["Market Value ($B)"] = a

# %%
df
# Out:
#       Rank                                   Company    Headquarters  \
# 0        1                             JPMorganChase   United States
# 1        2                        Berkshire Hathaway   United States
# 2        3                                      ICBC           China
# 3        4  Saudi Arabian Oil Company (Saudi Aramco)    Saudi Arabia
# 4        5                                    Amazon   United States
# ...    ...                                       ...             ...
# 1995  1996                               Dino Polska          Poland
# 1996  1997                        China Aviation Oil       Singapore
# 1997  1998                                      Jet2  United Kingdom
# 1998  1998                                Keiyo Bank           Japan
# 1999  1998                         PT Lippo Karawaci       Indonesia
#
#                           Industry  Sales ($B)  Profit ($B) Assets ($B)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               2000 non-null   int64
#  1   Company            2000 non-null   object
#  2   Headquarters       2000 non-null   object
#  3   Industry           2000 non-null   object
#  4   Sales ($B)         2000 non-null   float64
#  5   Profit ($B)        2000 non-null   float64
#  6   Assets ($B)        2000 non-null   object
#  7   Market Value ($B)  2000 non-null   object
#  8   Continent          2000 non-null   object
#  9   Profit Margin      2000 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 156.4+ KB

# %%
df["Market Value ($B)"] = df["Market Value ($B)"].astype(float)

# %%
df["S & Mv Ratio"] = df["Market Value ($B)"] / df["Sales ($B)"]
df.head()
# Out:
#    Rank                                   Company   Headquarters  \
# 0     1                             JPMorganChase  United States
# 1     2                        Berkshire Hathaway  United States
# 2     3                                      ICBC          China
# 3     4  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia
# 4     5                                    Amazon  United States
#
#                Industry  Sales ($B)  Profit ($B) Assets ($B)  \
# 0               Banking      285.11        59.36   4,357.86
# 1             Insurance      371.43        89.00   1,153.88
# 2               Banking      221.96        50.84    6,688.6
# 3  Oil & Gas Operations      480.15       104.97     645.03
# 4  Retail and Wholesale      637.96        59.25     624.89
#
#    Market Value ($B)      Continent Profit Margin  S & Mv Ratio
# 0             677.80  North America           20%      2.377328
# 1            1145.46  North America           23%      3.083919
# ...

# %%
ratio = df.groupby("Industry")["S & Mv Ratio"].mean()
ratio.sort_values(ascending = False)[1:4].plot(kind = "pie" , autopct = "%.2f%%")
# Out:
# <Axes: ylabel='S & Mv Ratio'>

# %%
ratio.sort_values(ascending = False)
# Out:
# Industry
# Drugs & Biotechnology                           inf
# IT Software & Services                    11.332369
# Semiconductors                             9.076583
# Diversified Financials                     6.263360
# Business Services & Supplies               5.587728
# Construction, Chemicals, Raw Materials     4.936047
# Technology Hardware & Equipment            4.009842
# Aerospace & Defense                        3.975700
# Health Care Equipment & Services           3.924913
# Utilities                                  3.705519
# Conglomerates                              3.627727
# Retail and Wholesale                       3.143833
# Household & Personal Products              2.981631
# Hotels, Restaurants & Leisure              2.720613
# Capital Goods                              2.542781
# Food, Drink & Tobacco                      2.449228
# Media                                      2.437855
# Chemicals                                  2.365604
# ...

# %% [markdown]
# # Q4

# %%
top_200 = df.sort_values(by = "Market Value ($B)" , ascending = False).head(200)

# %%
top_200
# Out:
#      Rank            Company   Headquarters                         Industry  \
# 10     11              Apple  United States  Technology Hardware & Equipment
# 9       9          Microsoft  United States           IT Software & Services
# 46     47             NVIDIA  United States                   Semiconductors
# 4       5             Amazon  United States             Retail and Wholesale
# 8       9           Alphabet  United States           IT Software & Services
# ..    ...                ...            ...                              ...
# 467   468        Investor AB         Sweden           Diversified Financials
# 115   116          UniCredit          Italy                          Banking
# 77     78          Munich Re        Germany                        Insurance
# 227   228  Micron Technology  United States                   Semiconductors
# 154   155           SK Hynix    South Korea                   Semiconductors
#
# ...

# %%
most_profit = top_200.sort_values(by = "Profit ($B)" , ascending = False).head(5)
least_profit = top_200.sort_values(by = "Profit ($B)" , ascending = False).tail(5)

# %%
most_profit[["Company" , "Profit ($B)"]]
# Out:
#                                      Company  Profit ($B)
# 8                                   Alphabet       111.00
# 3   Saudi Arabian Oil Company (Saudi Aramco)       104.97
# 10                                     Apple        96.15
# 9                                  Microsoft        92.75
# 1                         Berkshire Hathaway        89.00

# %%
plt.barh(most_profit["Company"] , most_profit["Profit ($B)"] , color = "skyblue")
plt.title("Top 5 Most Profitable Companies")
plt.xlabel("Company Name")
plt.ylabel("Profit (in $Billion)")
plt.show()

# %%
least_profit[["Company" , "Profit ($B)"]]
# Out:
#                      Company  Profit ($B)
# 1489             CrowdStrike      -0.0193
# 959   Vertex Pharmaceuticals      -0.5356
# 608                   Safran      -0.7215
# 1183           MicroStrategy      -1.1700
# 448                   Boeing     -11.5100

# %%
plt.barh(least_profit["Company"] , least_profit["Profit ($B)"] , color = "skyblue")
plt.title("Top 5 Least Profitable Companies")
plt.xlabel("Company Name")
plt.ylabel("Profit (in $Billion)")
plt.show()

# %% [markdown]
# # Q5

# %%
df.head()
# Out:
#    Rank                                   Company   Headquarters  \
# 0     1                             JPMorganChase  United States
# 1     2                        Berkshire Hathaway  United States
# 2     3                                      ICBC          China
# 3     4  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia
# 4     5                                    Amazon  United States
#
#                Industry  Sales ($B)  Profit ($B) Assets ($B)  \
# 0               Banking      285.11        59.36   4,357.86
# 1             Insurance      371.43        89.00   1,153.88
# 2               Banking      221.96        50.84    6,688.6
# 3  Oil & Gas Operations      480.15       104.97     645.03
# 4  Retail and Wholesale      637.96        59.25     624.89
#
#    Market Value ($B)      Continent Profit Margin  S & Mv Ratio
# 0             677.80  North America           20%      2.377328
# 1            1145.46  North America           23%      3.083919
# ...

# %%
co_sales = df.groupby("Headquarters")["Sales ($B)"].sum()
top5_sales = co_sales.sort_values(ascending = False)[:5]
top5_sales = pd.DataFrame(top5_sales)
top5_sales = top5_sales.reset_index()
top5_sales
# Out:
#      Headquarters  Sales ($B)
# 0   United States   19496.513
# 1           China    7810.667
# 2           Japan    4239.706
# 3         Germany    2262.260
# 4  United Kingdom    2134.903

# %%
co_profit = df.groupby("Headquarters")["Profit ($B)"].sum()
top5_profit = co_profit.sort_values(ascending = False)[:5]
top5_profit = pd.DataFrame(top5_profit)
top5_profit = top5_profit.reset_index()
top5_profit
# Out:
#      Headquarters  Profit ($B)
# 0   United States    2024.0454
# 1           China     654.0211
# 2           Japan     297.1260
# 3  United Kingdom     164.1344
# 4    Saudi Arabia     135.7982

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               2000 non-null   int64
#  1   Company            2000 non-null   object
#  2   Headquarters       2000 non-null   object
#  3   Industry           2000 non-null   object
#  4   Sales ($B)         2000 non-null   float64
#  5   Profit ($B)        2000 non-null   float64
#  6   Assets ($B)        2000 non-null   object
#  7   Market Value ($B)  2000 non-null   float64
#  8   Continent          2000 non-null   object
#  9   Profit Margin      2000 non-null   object
#  10  S & Mv Ratio       2000 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 172.0+ KB

# %%
assests = list(df["Assets ($B)"])
count = 0
a = []
b = []
for i in assests:
    try : 
        i = float(i)
        a.append(i)
    except:
        i = i.replace("," , "")
        a.append(i)

# %%
print(count)
print(b)
# Out:
# 40
# ['4,357.86 ', '1,153.88 ', '6,688.6 ', '3,349.42 ', '5,558.26 ', '5,923.64 ', '4,855.83 ', '3,017.05 ', '1,950.31 ', '1,766', '2,571.51 ', '1,300.3 ', '1,081.66 ', '1,512.88 ', '1,775.23 ', '1,902.3 ', '2,629.12 ', '2,800.93 ', '1,664.83 ', '1,445.58 ', '1,977.94 ', '2,041.4 ', '2,340.64 ', '1,565.03 ', '2,391.78 ', '1,440.47 ', '1,013.7 ', '1,815.93 ', '1,654.34 ', '1,305.99 ', '1,440.41 ', '1,901.4 ', '1,296.28 ', '1,135.55 ', '1,629.41 ', '1,056.77 ', '1,958.28 ', '1,070.65 ', '4,349.73 ', '3,386.74 ']

# %%
df["Assets ($B)"] = a
df["Assets ($B)"] = df["Assets ($B)"].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               2000 non-null   int64
#  1   Company            2000 non-null   object
#  2   Headquarters       2000 non-null   object
#  3   Industry           2000 non-null   object
#  4   Sales ($B)         2000 non-null   float64
#  5   Profit ($B)        2000 non-null   float64
#  6   Assets ($B)        2000 non-null   float64
#  7   Market Value ($B)  2000 non-null   float64
#  8   Continent          2000 non-null   object
#  9   Profit Margin      2000 non-null   object
#  10  S & Mv Ratio       2000 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 172.0+ KB

# %%
co_assets = df.groupby("Headquarters")["Assets ($B)"].sum()
top5_assets = co_assets.sort_values(ascending = False)[:5]
top5_assets = pd.DataFrame(top5_assets)
top5_assets = top5_assets.reset_index()
top5_assets
# Out:
#      Headquarters  Assets ($B)
# 0   United States    61089.901
# 1           China    57413.477
# 2           Japan    20108.550
# 3  United Kingdom    13782.580
# 4          France    10157.930

# %%
co_mv = df.groupby("Headquarters")["Market Value ($B)"].sum()
top5_mv = co_mv.sort_values(ascending = False)[:5]
top5_mv = pd.DataFrame(top5_mv)
top5_mv = top5_mv.reset_index()
top5_mv
# Out:
#      Headquarters  Market Value ($B)
# 0   United States          50221.953
# 1           China           7100.978
# 2           Japan           4094.188
# 3  United Kingdom           2851.650
# 4          France           2705.740

# %%
fig , ax = plt.subplots(2,2)

ax[0,0].pie(top5_sales["Sales ($B)"], labels = top5_sales["Headquarters"] ,autopct = "%.f%%" , radius = 1)
ax[0,0].set_title("Top 5 Countries by Sales")

ax[0,1].pie(top5_profit["Profit ($B)"],labels = top5_profit["Headquarters"] , autopct = "%.f%%" , radius = 1)
ax[0,1].set_title("Top 5 Countries by Profit")

ax[1,0].pie( top5_assets["Assets ($B)"],labels = top5_assets["Headquarters"] , autopct = "%.f%%" , radius = 1)
ax[1,0].set_title("Top 5 Countries by Assets")

ax[1,1].pie( top5_mv["Market Value ($B)"], labels = top5_mv["Headquarters"] ,autopct = "%.f%%" , radius = 1)
ax[1,1].set_title("Top 5 Countries by Market Value")

plt.tight_layout()
plt.show()

# %%
colors =
